# %% [markdown]
# <a href="https://colab.research.google.com/github/moggyyy4u/MiltonMog/blob/main/Pandas_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7dd12c38-6d3c-47d1-b843-95a58b0e0609" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7dd12c38-6d3c-47d1-b843-95a58b0e0609">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Crop Production data.csv')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4087972447.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('Crop Production data.csv')
#       4 print(df.head())
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Crop Production data.csv')  # or use your DataFrame
print(df.head())     # Shows the first 5 rows
print(df.info())     # Data types + missing values summary
print(df.describe()) # Summary statistics for numeric columns
# Out:
#             State_Name    District_Name  Crop_Year       Season  \
# 0  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 1  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 2  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 3  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
# 4  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
# ...

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB
# None

# %%
df.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Season']=df["Season"].str.strip()

# %%
df['Crop'].unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Mesta', 'Cowpea(Lobia)',
#        'Lemon', 'Pome Granet', 'Sapota', 'Cabbage', 'Rapeseed &Mustard',
# ...

# %% [markdown]
# 'Rice', 'Banana','Maize','Wheat','Tea','Coffee','Pineapple','Apple','Peach','Pear','Tomato','Bean','Yam','Garlic','Ginger'

# %%
selected_crops=['Rice', 'Banana','Maize','Wheat','Tea','Coffee','Pineapple','Apple','Peach','Pear','Tomato','Bean','Yam','Garlic','Ginger']
df1=df[df['Crop'].isin(selected_crops)]
df1
# Out:
#                  State_Name    District_Name  Crop_Year       Season    Crop  \
# 2       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif         Rice
# 3       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year   Banana
# 12      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Kharif         Rice
# 18      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2002  Kharif         Rice
# 20      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2002  Whole Year   Banana
# ...                     ...              ...        ...          ...     ...
# 246058          West Bengal         PURULIYA       2014  Autumn         Rice
# 246084          West Bengal         PURULIYA       2014  Rabi          Wheat
# 246085          West Bengal         PURULIYA       2014  Summer        Maize
# 246086          West Bengal         PURULIYA       2014  Summer         Rice
# 246089          West Bengal         PURULIYA       2014  Winter         Rice
#
#             Area  Production
# ...

# %%
features = df1.drop(columns='Production')
features
# Out:
#                  State_Name    District_Name  Crop_Year       Season    Crop  \
# 2       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif         Rice
# 3       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year   Banana
# 12      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Kharif         Rice
# 18      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2002  Kharif         Rice
# 20      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2002  Whole Year   Banana
# ...                     ...              ...        ...          ...     ...
# 246058          West Bengal         PURULIYA       2014  Autumn         Rice
# 246084          West Bengal         PURULIYA       2014  Rabi          Wheat
# 246085          West Bengal         PURULIYA       2014  Summer        Maize
# 246086          West Bengal         PURULIYA       2014  Summer         Rice
# 246089          West Bengal         PURULIYA       2014  Winter         Rice
#
#             Area
# 2          102.0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ehe.fit_transform(features)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 266652 stored elements and shape (44442, 20986)>

# %%
features
# Out:
#                  State_Name    District_Name  Crop_Year       Season    Crop  \
# 2       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif         Rice
# 3       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year   Banana
# 12      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Kharif         Rice
# 18      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2002  Kharif         Rice
# 20      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2002  Whole Year   Banana
# ...                     ...              ...        ...          ...     ...
# 246058          West Bengal         PURULIYA       2014  Autumn         Rice
# 246084          West Bengal         PURULIYA       2014  Rabi          Wheat
# 246085          West Bengal         PURULIYA       2014  Summer        Maize
# 246086          West Bengal         PURULIYA       2014  Summer         Rice
# 246089          West Bengal         PURULIYA       2014  Winter         Rice
#
#             Area
# 2          102.0
# ...

# %%
ehe=OneHotEncoder()
