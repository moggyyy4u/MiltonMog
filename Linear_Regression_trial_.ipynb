# %% [markdown]
# <a href="https://colab.research.google.com/github/moggyyy4u/MiltonMog/blob/main/Linear_Regression_trial_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['big_mart_sales.csv']))

df.head()
# Out:
#      <input type="file" id="files-8bdc3991-f56b-4235-997c-fd09b2e04996" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bdc3991-f56b-4235-997c-fd09b2e04996">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df['Item_Weight'] = df.groupby('Item_Type')['Item_Weight'].transform(lambda x: x.fillna(x.mean()))

# %%
df['Outlet_Size'] = df.groupby('Outlet_Type')['Outlet_Size'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df['Years_Active'] = 2026 - df['Outlet_Establishment_Year']

# %%
y=df['Item_Outlet_Sales']
x=df.drop(['Item_Outlet_Sales','Outlet_Identifier','Item_Identifier','Outlet_Establishment_Year'], axis=1)
x.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Years_Active'],
#       dtype='object')

# %%
import pandas as pd
categorical_cols = ['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type']
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_test.head()
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 7503     14.30000          Low Fat         0.026300        Frozen Foods
# 2957      7.93000          Low Fat         0.071136  Health and Hygiene
# 7031     14.50000          Regular         0.041313              Canned
# 1084     11.84746          Regular         0.044767         Soft Drinks
# 856      10.19500          Regular         0.012456                Meat
#
#       Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 7503   79.4302        High               Tier 3  Supermarket Type1
# 2957   42.7086       Small               Tier 1  Supermarket Type1
# 7031   42.0454      Medium               Tier 1  Supermarket Type1
# 1084  173.7054      Medium               Tier 3  Supermarket Type3
# 856   197.5110       Small               Tier 2  Supermarket Type1
#
#       Years_Active
# 7503            39
# 2957            29
# 7031            27
# 1084            41
# 856             22

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10559/3525162394.py in <cell line: 0>()
#       2
#       3 model = LinearRegression()
# ----> 4 model.fit(x_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...
